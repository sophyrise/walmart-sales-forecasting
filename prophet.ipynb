# %% [markdown]
# # Model Experiment — `Prophet`

# %% [markdown]
# ## Setup

# %%
import pathlib
if pathlib.Path('/kaggle/input').exists():
    # !pip install -q prophet wandb python-dotenv mlflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 97.8 MB/s eta 0:00:00:00:01:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 95.7 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 77.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.0/212.0 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.0/121.0 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.2/132.2 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.6/954.6 kB 48.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.9/214.9 kB 16.2 MB/s eta 0:00:00

# %% [markdown]
# ## 0. Config

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

KAGGLE_INPUT = Path('/kaggle/input')
KAGGLE_COMPETITION = 'walmart-recruiting-store-sales-forecasting'
ON_KAGGLE = KAGGLE_INPUT.exists()

if ON_KAGGLE:
    WORKING_DIR = Path('/kaggle/working')
else:
    PROJECT_ROOT = Path.cwd().parent
    WORKING_DIR = PROJECT_ROOT
    load_dotenv(PROJECT_ROOT / '.env')

def _find_file(stem):

    names = (f'{stem}.csv', f'{stem}.csv.zip')
    if ON_KAGGLE:
        search_roots = [
            KAGGLE_INPUT / KAGGLE_COMPETITION,
            KAGGLE_INPUT / 'competitions' / KAGGLE_COMPETITION,
        ]
        for root in search_roots:
            if root.exists():
                for name in names:
                    p = root / name
                    if p.exists():
                        return p
        for name in names:
            matches = list(KAGGLE_INPUT.rglob(name))
            if matches:
                return matches[0]
        raise FileNotFoundError(
            f"Could not find {stem}.csv[.zip] anywhere under {KAGGLE_INPUT}. "
            f"Contents of {KAGGLE_INPUT}: {list(KAGGLE_INPUT.iterdir())}"
        )
    else:
        p = PROJECT_ROOT / 'data' / 'raw' / f'{stem}.csv'
        if not p.exists():
            raise FileNotFoundError(f'{p} not found')
        return p

TRAIN_CSV = _find_file('train')
TEST_CSV = _find_file('test')
FEATURES_CSV = _find_file('features')
STORES_CSV = _find_file('stores')

RANDOM_SEED = 42
TARGET = 'Weekly_Sales'
HOLIDAY_WEIGHT = 5
NON_HOLIDAY_WEIGHT = 1

if ON_KAGGLE:
    try:
        from kaggle_secrets import UserSecretsClient
        client = UserSecretsClient()
        for key in ('MLFLOW_TRACKING_URI', 'MLFLOW_TRACKING_USERNAME', 'MLFLOW_TRACKING_PASSWORD', 'WANDB_API_KEY'):
            try:
                os.environ.setdefault(key, client.get_secret(key))
            except Exception:
                pass
    except Exception:
        pass

MLFLOW_TRACKING_URI = os.getenv('MLFLOW_TRACKING_URI')
MLFLOW_TRACKING_USERNAME = os.getenv('MLFLOW_TRACKING_USERNAME')
MLFLOW_TRACKING_PASSWORD = os.getenv('MLFLOW_TRACKING_PASSWORD')

print('On Kaggle:', ON_KAGGLE)
print('train:', TRAIN_CSV)
print('test:', TEST_CSV)
print('features:', FEATURES_CSV)
print('stores:', STORES_CSV)
# Out:
# On Kaggle: True
# train: /kaggle/input/competitions/walmart-recruiting-store-sales-forecasting/train.csv.zip
# test: /kaggle/input/competitions/walmart-recruiting-store-sales-forecasting/test.csv.zip
# features: /kaggle/input/competitions/walmart-recruiting-store-sales-forecasting/features.csv.zip
# stores: /kaggle/input/competitions/walmart-recruiting-store-sales-forecasting/stores.csv

# %% [markdown]
# ## 1. Data loading helpers

# %%
import pandas as pd

def _read_bool(series):
    if series.dtype == bool:
        return series
    return series.astype(str).str.strip().str.upper().map({'TRUE': True, 'FALSE': False})

def load_stores():
    return pd.read_csv(STORES_CSV)

def load_features():
    df = pd.read_csv(FEATURES_CSV, parse_dates=['Date'])
    df['IsHoliday'] = _read_bool(df['IsHoliday'])
    df = df.sort_values(['Store', 'Date'])
    for col in ('CPI', 'Unemployment'):
        df[col] = df.groupby('Store')[col].transform(lambda s: s.ffill().bfill())
    return df.reset_index(drop=True)

def load_raw(split):
    path = TRAIN_CSV if split == 'train' else TEST_CSV
    df = pd.read_csv(path, parse_dates=['Date'])
    df['IsHoliday'] = _read_bool(df['IsHoliday'])
    return df

def load_merged(split='train'):
    base = load_raw(split)
    stores = load_stores()
    feats = load_features().drop(columns=['IsHoliday'])
    df = base.merge(stores, on='Store', how='left')
    df = df.merge(feats, on=['Store', 'Date'], how='left')
    df = df.sort_values(['Store', 'Dept', 'Date']).reset_index(drop=True)
    return df

# %% [markdown]
# ## 2. Metric (WMAE) & cross-validation helpers

# %%
def weights_from_holiday(is_holiday):
    is_holiday = np.asarray(is_holiday).astype(bool)
    return np.where(is_holiday, HOLIDAY_WEIGHT, NON_HOLIDAY_WEIGHT).astype(float)

def wmae(y_true, y_pred, is_holiday):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    w = weights_from_holiday(is_holiday)
    return float(np.sum(w * np.abs(y_true - y_pred)) / np.sum(w))

# %%
def _sorted_unique_dates(dates):
    return np.sort(pd.to_datetime(dates).unique())

def time_holdout(df, weeks=8, date_col='Date'):
    uniq = _sorted_unique_dates(df[date_col])
    if weeks >= len(uniq):
        raise ValueError(f'weeks={weeks} >= number of distinct weeks {len(uniq)}')
    cutoff = uniq[-weeks]
    d = pd.to_datetime(df[date_col]).to_numpy()
    train_idx = np.where(d < cutoff)[0]
    val_idx = np.where(d >= cutoff)[0]
    return train_idx, val_idx

def expanding_splits(df, n_splits=3, horizon=8, date_col='Date'):
    uniq = _sorted_unique_dates(df[date_col])
    needed = horizon * n_splits
    if needed >= len(uniq):
        raise ValueError(f'Need > {needed} distinct weeks for {n_splits} folds of {horizon}; have {len(uniq)}.')
    d = pd.to_datetime(df[date_col]).to_numpy()
    for k in range(n_splits):
        end_offset = needed - k * horizon
        start_offset = end_offset - horizon
        val_start = uniq[-end_offset]
        val_end = uniq[-start_offset] if start_offset > 0 else None
        train_idx = np.where(d < val_start)[0]
        if val_end is None:
            val_idx = np.where(d >= val_start)[0]
        else:
            val_idx = np.where((d >= val_start) & (d < val_end))[0]
        yield train_idx, val_idx

# %% [markdown]
# ## 3. Holiday effects & shared helpers

# %%
SUPER_BOWL = pd.to_datetime(['2010-02-12', '2011-02-11', '2012-02-10', '2013-02-08'])
LABOR_DAY = pd.to_datetime(['2010-09-10', '2011-09-09', '2012-09-07', '2013-09-06'])
THANKSGIVING = pd.to_datetime(['2010-11-26', '2011-11-25', '2012-11-23', '2013-11-29'])
CHRISTMAS = pd.to_datetime(['2010-12-31', '2011-12-30', '2012-12-28', '2013-12-27'])

def build_holidays_df():
    frames = []
    for name, dates in [('SuperBowl', SUPER_BOWL), ('LaborDay', LABOR_DAY),
                         ('Thanksgiving', THANKSGIVING), ('Christmas', CHRISTMAS)]:
        frames.append(pd.DataFrame({'holiday': name, 'ds': dates, 'lower_window': 0, 'upper_window': 0}))
    return pd.concat(frames, ignore_index=True)

HOLIDAYS_DF = build_holidays_df()

def cold_start_fallback_table(df, value_col='Weekly_Sales'):

    fallback_per_key = df.groupby(['Store', 'Dept'])[value_col].apply(lambda s: s.tail(8).mean())
    dept_mean = df.groupby('Dept')[value_col].mean()
    global_mean = float(df[value_col].mean())
    return fallback_per_key, dept_mean, global_mean

# %% [markdown]
# ## 4. Weights & Biases setup

# %%
import wandb
import numpy as np, pandas as pd

MODEL_NAME = 'Prophet'
WANDB_PROJECT = 'walmart-sales-forecasting'
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#   2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#   ········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: sgurj22 (TwoMusketeers) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ## 5. MLflow tracking setup

# %%
import mlflow

def init_tracking(experiment=None):
    uri = MLFLOW_TRACKING_URI
    if uri:

        if 'dagshub.com' in uri and not uri.rstrip('/').endswith('.mlflow'):
            uri = uri.rstrip('/') + '.mlflow'
            print(f'NOTE: appended .mlflow to MLFLOW_TRACKING_URI (DagsHub requires it) -> {uri}')
        mlflow.set_tracking_uri(uri)
        if MLFLOW_TRACKING_USERNAME:
            os.environ['MLFLOW_TRACKING_USERNAME'] = MLFLOW_TRACKING_USERNAME
        if MLFLOW_TRACKING_PASSWORD:
            os.environ['MLFLOW_TRACKING_PASSWORD'] = MLFLOW_TRACKING_PASSWORD
    else:

        print('WARNING: MLFLOW_TRACKING_URI not set -- check Add-ons > Secrets is attached to THIS notebook.')
        print('Falling back to a LOCAL sqlite store: this will NOT persist beyond this session and your team will not see it.')
        mlflow.set_tracking_uri(f"sqlite:///{WORKING_DIR / 'mlflow.db'}")
    if experiment:
        mlflow.set_experiment(experiment)
    return mlflow.get_tracking_uri()

EXPERIMENT = f'{MODEL_NAME}_Training'
mlflow_uri = init_tracking(EXPERIMENT)
print('MLflow ->', mlflow_uri, '| experiment:', EXPERIMENT)
# Out:
# WARNING: MLFLOW_TRACKING_URI not set -- check Add-ons > Secrets is attached to THIS notebook.
# Falling back to a LOCAL sqlite store: this will NOT persist beyond this session and your team will not see it.
# 2026/07/17 09:07:02 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/07/17 09:07:02 INFO mlflow.store.db.utils: Updating database tables
# 2026/07/17 09:07:04 INFO mlflow.tracking.fluent: Experiment with name 'Prophet_Training' does not exist. Creating a new experiment.
# MLflow -> sqlite:////kaggle/working/mlflow.db | experiment: Prophet_Training

# %% [markdown]
# ## Load raw data

# %%
raw_train = load_raw('train')
raw_test  = load_raw('test')
raw_train.shape, raw_test.shape
# Out:
# ((421570, 5), (115064, 4))

# %% [markdown]
# ## Run 1 — Cleaning

# %%
n_series = raw_train.groupby(['Store', 'Dept']).ngroups
lengths = raw_train.groupby(['Store', 'Dept']).size()
span_weeks = raw_train.groupby(['Store', 'Dept'])['Date'].agg(lambda d: (d.max() - d.min()).days // 7 + 1)
n_with_gaps = int((lengths < span_weeks).sum())
n_negative_sales = int((raw_train['Weekly_Sales'] < 0).sum())

cleaning_stats = {
    'n_train_rows': len(raw_train),
    'n_series': n_series,
    'n_series_with_gaps': n_with_gaps,
    'n_negative_sales': n_negative_sales,
}

with mlflow.start_run(run_name=f'{MODEL_NAME}_Cleaning'):
    for k, v in cleaning_stats.items():
        mlflow.log_metric(k, v)

run = wandb.init(project=WANDB_PROJECT, group=MODEL_NAME, job_type='cleaning', name=f'{MODEL_NAME}_Cleaning')
wandb.log(cleaning_stats)
run.finish()
print(f'{n_series} series, {n_with_gaps} with missing weeks, {n_negative_sales} negative Weekly_Sales rows')
# Out:
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_090706-ugz60fox</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/ugz60fox' target="_blank">Prophet_Cleaning</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/ugz60fox' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/ugz60fox</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>n_negative_sales</td><td>▁</td></tr><tr><td>n_series</td><td>▁</td></tr><tr><td>n_series_with_gaps</td><td>▁</td></tr><tr><td>n_train_rows</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>n_negative_sales</td><td>1285</td></tr><tr><td>n_series</td><td>3331</td></tr><tr><td>n_series_with_gaps</td><td>605</td></tr><tr><td>n_train_rows</td><td>421570</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_Cleaning</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/ugz60fox' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/ugz60fox</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_090706-ugz60fox/logs</code>
# 3331 series, 605 with missing weeks, 1285 negative Weekly_Sales rows

# %% [markdown]
# ## Run 2 — "Feature Selection" (informational)

# %%
feature_selection_decisions = {
    'holidays_used': 'SuperBowl, LaborDay, Thanksgiving, Christmas (native Prophet holiday-effect term)',
    'extra_regressors_used': 'none (add_regressor deliberately not used, see Theory)',
    'weekly_seasonality': False,
    'yearly_seasonality': True,
    'reasoning': 'per-series fits keep exogenous regressors fragile/unnecessary here; '
                 'LightGBM.ipynb/XGBoost.ipynb already cover that signal with a global model',
}

with mlflow.start_run(run_name=f'{MODEL_NAME}_Feature_Selection'):
    for k, v in feature_selection_decisions.items():
        mlflow.log_param(k, v)

run = wandb.init(project=WANDB_PROJECT, group=MODEL_NAME, job_type='feature_selection', name=f'{MODEL_NAME}_Feature_Selection')
wandb.config.update(feature_selection_decisions)
run.finish()
for k, v in feature_selection_decisions.items():
    print(f'{k}: {v}')
# Out:
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_090714-bocsjxkw</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/bocsjxkw' target="_blank">Prophet_Feature_Selection</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/bocsjxkw' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/bocsjxkw</a>
#  View run <strong style="color:#cdcd00">Prophet_Feature_Selection</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/bocsjxkw' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/bocsjxkw</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_090714-bocsjxkw/logs</code>
# holidays_used: SuperBowl, LaborDay, Thanksgiving, Christmas (native Prophet holiday-effect term)
# extra_regressors_used: none (add_regressor deliberately not used, see Theory)
# weekly_seasonality: False
# yearly_seasonality: True
# reasoning: per-series fits keep exogenous regressors fragile/unnecessary here; LightGBM.ipynb/XGBoost.ipynb already cover that signal with a global model

# %% [markdown]
# ## 6. Pipeline wrapper (raw-test-ready)

# %%
from sklearn.base import BaseEstimator, RegressorMixin
import logging
logging.getLogger('cmdstanpy').disabled = True
logging.getLogger('cmdstanpy').setLevel(logging.CRITICAL)
logging.getLogger('prophet').setLevel(logging.WARNING)
from prophet import Prophet

class PerSeriesProphetForecaster(BaseEstimator, RegressorMixin):

    def __init__(self, changepoint_prior_scale=0.05, seasonality_prior_scale=10.0,
                 seasonality_mode='additive', holidays_prior_scale=10.0, min_obs=20):
        self.changepoint_prior_scale = changepoint_prior_scale
        self.seasonality_prior_scale = seasonality_prior_scale
        self.seasonality_mode = seasonality_mode
        self.holidays_prior_scale = holidays_prior_scale
        self.min_obs = min_obs

    def fit(self, X, y=None):
        df = X.copy()
        df['Weekly_Sales'] = np.asarray(y, dtype=float)

        self.models_ = {}
        self.last_date_ = {}
        fallback_per_key, self.dept_mean_, self.global_mean_ = cold_start_fallback_table(df)
        self.fallback_value_ = fallback_per_key.to_dict()

        n_failed = 0
        for key, g in df.groupby(['Store', 'Dept']):
            g = g.sort_values('Date').drop_duplicates('Date')
            s = g.set_index('Date')['Weekly_Sales']
            self.last_date_[key] = s.index.max()
            if len(s) < self.min_obs:
                self.models_[key] = None
                continue
            try:
                pdf = pd.DataFrame({'ds': s.index, 'y': s.to_numpy()})
                m = Prophet(
                    changepoint_prior_scale=self.changepoint_prior_scale,
                    seasonality_prior_scale=self.seasonality_prior_scale,
                    seasonality_mode=self.seasonality_mode,
                    holidays_prior_scale=self.holidays_prior_scale,
                    yearly_seasonality=True, weekly_seasonality=False, daily_seasonality=False,
                    holidays=HOLIDAYS_DF,
                )
                m.fit(pdf)
                self.models_[key] = m
            except Exception:
                self.models_[key] = None
                n_failed += 1

        self.n_series_ = df.groupby(['Store', 'Dept']).ngroups
        self.n_failed_ = n_failed
        return self

    def _fallback(self, key, dept):
        if key in self.fallback_value_:
            return self.fallback_value_[key]
        if dept in self.dept_mean_.index:
            return float(self.dept_mean_.loc[dept])
        return self.global_mean_

    def predict(self, X):
        preds = np.empty(len(X), dtype=float)
        X = X.reset_index(drop=True)
        for (store, dept), idx in X.groupby(['Store', 'Dept']).groups.items():
            key = (store, dept)
            rows = X.loc[idx]
            if key not in self.models_ or self.models_[key] is None:
                preds[idx] = self._fallback(key, dept)
                continue
            future = pd.DataFrame({'ds': pd.to_datetime(rows['Date'])})
            try:
                fc = self.models_[key].predict(future)
                preds[idx] = fc['yhat'].to_numpy()
            except Exception:
                preds[idx] = self._fallback(key, dept)
        return np.clip(preds, 0, None)

# %% [markdown]
# ## Run 3 — Cross-validation (curated hyperparameter search)

# %%
import itertools

SAMPLE_SIZE = 150
hp_idx, _ = time_holdout(raw_train, weeks=39)
raw_train_hp = raw_train.iloc[hp_idx].reset_index(drop=True)
rng = np.random.RandomState(RANDOM_SEED)
all_keys = list(raw_train_hp.groupby(['Store', 'Dept']).groups.keys())
sample_keys = [all_keys[i] for i in rng.choice(len(all_keys), size=min(SAMPLE_SIZE, len(all_keys)), replace=False)]
sample_mask = raw_train_hp.set_index(['Store', 'Dept']).index.isin(sample_keys)
sample_df = raw_train_hp[sample_mask].reset_index(drop=True)
print('CV sample:', len(sample_keys), 'series,', len(sample_df), 'rows')

candidate_changepoint_prior_scale = [0.01, 0.05, 0.1, 0.5]
candidate_seasonality_prior_scale = [1.0, 10.0, 25.0]
candidate_seasonality_mode = ['additive', 'multiplicative']
candidate_holidays_prior_scale = [1.0, 10.0]

configs = [
    {'changepoint_prior_scale': cp, 'seasonality_prior_scale': sp, 'seasonality_mode': sm, 'holidays_prior_scale': hp}
    for cp, sp, sm, hp in itertools.product(
        candidate_changepoint_prior_scale, candidate_seasonality_prior_scale,
        candidate_seasonality_mode, candidate_holidays_prior_scale,
    )
]
print(len(configs), 'configs to try')

trial_results = []
with mlflow.start_run(run_name=f'{MODEL_NAME}_CV'):
    mlflow.log_param('n_configs', len(configs))
    mlflow.log_param('n_folds', 3)
    mlflow.log_param('sample_size_series', len(sample_keys))
    for i, cfg in enumerate(configs):
        run = wandb.init(project=WANDB_PROJECT, group=MODEL_NAME, job_type='cv', name=f'{MODEL_NAME}_CV_trial{i}', config=cfg, reinit=True)
        fold_scores = []
        for k, (tr_idx, va_idx) in enumerate(expanding_splits(sample_df, n_splits=3, horizon=8)):
            tr, va = sample_df.iloc[tr_idx], sample_df.iloc[va_idx]
            pipe = PerSeriesProphetForecaster(**cfg)
            pipe.fit(tr, tr['Weekly_Sales'])
            pred = pipe.predict(va)
            score = wmae(va['Weekly_Sales'], pred, va['IsHoliday'])
            fold_scores.append(score)
            wandb.log({'fold': k, 'fold_wmae': score})
        cv_mean = float(np.mean(fold_scores))
        wandb.log({'cv_wmae_mean': cv_mean, 'cv_wmae_std': float(np.std(fold_scores))})
        run.finish()
        trial_results.append({'config': cfg, 'cv_wmae_mean': cv_mean})
        cfg_tag = f"cp{cfg['changepoint_prior_scale']}_sp{cfg['seasonality_prior_scale']}_{cfg['seasonality_mode']}_hp{cfg['holidays_prior_scale']}"
        mlflow.log_metric(f'wmae_{cfg_tag}', cv_mean)
        print(f'config {i} {cfg}: CV WMAE={cv_mean:,.1f}')

    best_trial = min(trial_results, key=lambda t: t['cv_wmae_mean'])
    best_config = best_trial['config']
    mlflow.log_param('best_config', best_config)
    mlflow.log_metric('best_cv_wmae', best_trial['cv_wmae_mean'])

print('best config:', best_config, '| CV WMAE:', best_trial['cv_wmae_mean'])
# Out:
# CV sample: 150 series, 14314 rows
# 48 configs to try
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_090722-abar85fy</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/abar85fy' target="_blank">Prophet_CV_trial0</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/abar85fy' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/abar85fy</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2051.86654</td></tr><tr><td>cv_wmae_std</td><td>424.69521</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2552.976</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial0</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/abar85fy' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/abar85fy</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_090722-abar85fy/logs</code>
# config 0 {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 1.0, 'seasonality_mode': 'additive', 'holidays_prior_scale': 1.0}: CV WMAE=2,051.9
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_090927-204rfhcw</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/204rfhcw' target="_blank">Prophet_CV_trial1</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/204rfhcw' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/204rfhcw</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2053.85119</td></tr><tr><td>cv_wmae_std</td><td>427.34889</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2559.40025</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial1</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/204rfhcw' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/204rfhcw</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_090927-204rfhcw/logs</code>
# config 1 {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 1.0, 'seasonality_mode': 'additive', 'holidays_prior_scale': 10.0}: CV WMAE=2,053.9
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_091138-4rw0tp45</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/4rw0tp45' target="_blank">Prophet_CV_trial2</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/4rw0tp45' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/4rw0tp45</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2045.88395</td></tr><tr><td>cv_wmae_std</td><td>277.1282</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2367.97012</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial2</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/4rw0tp45' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/4rw0tp45</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_091138-4rw0tp45/logs</code>
# config 2 {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 1.0, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 1.0}: CV WMAE=2,045.9
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_091344-pnc62d3j</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/pnc62d3j' target="_blank">Prophet_CV_trial3</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/pnc62d3j' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/pnc62d3j</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>1998.55146</td></tr><tr><td>cv_wmae_std</td><td>384.80957</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2394.73918</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial3</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/pnc62d3j' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/pnc62d3j</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_091344-pnc62d3j/logs</code>
# config 3 {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 1.0, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 10.0}: CV WMAE=1,998.6
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_091553-ynqx6rnh</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/ynqx6rnh' target="_blank">Prophet_CV_trial4</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/ynqx6rnh' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/ynqx6rnh</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2058.50647</td></tr><tr><td>cv_wmae_std</td><td>428.83608</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2567.49936</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial4</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/ynqx6rnh' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/ynqx6rnh</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_091553-ynqx6rnh/logs</code>
# config 4 {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'additive', 'holidays_prior_scale': 1.0}: CV WMAE=2,058.5
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_091758-qwhmjqtv</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/qwhmjqtv' target="_blank">Prophet_CV_trial5</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/qwhmjqtv' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/qwhmjqtv</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2058.96376</td></tr><tr><td>cv_wmae_std</td><td>431.93364</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2571.65274</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial5</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/qwhmjqtv' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/qwhmjqtv</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_091758-qwhmjqtv/logs</code>
# config 5 {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'additive', 'holidays_prior_scale': 10.0}: CV WMAE=2,059.0
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_092011-n3bf1mhs</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/n3bf1mhs' target="_blank">Prophet_CV_trial6</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/n3bf1mhs' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/n3bf1mhs</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2063.07617</td></tr><tr><td>cv_wmae_std</td><td>302.63384</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2428.6423</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial6</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/n3bf1mhs' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/n3bf1mhs</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_092011-n3bf1mhs/logs</code>
# config 6 {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 1.0}: CV WMAE=2,063.1
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_092223-qh40gtdk</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/qh40gtdk' target="_blank">Prophet_CV_trial7</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/qh40gtdk' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/qh40gtdk</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2012.29526</td></tr><tr><td>cv_wmae_std</td><td>400.64897</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2434.70017</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial7</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/qh40gtdk' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/qh40gtdk</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_092223-qh40gtdk/logs</code>
# config 7 {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 10.0}: CV WMAE=2,012.3
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_092434-wez1sq08</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/wez1sq08' target="_blank">Prophet_CV_trial8</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/wez1sq08' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/wez1sq08</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2064.72907</td></tr><tr><td>cv_wmae_std</td><td>427.92465</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2568.56107</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial8</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/wez1sq08' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/wez1sq08</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_092434-wez1sq08/logs</code>
# config 8 {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 25.0, 'seasonality_mode': 'additive', 'holidays_prior_scale': 1.0}: CV WMAE=2,064.7
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_092641-3oglv933</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/3oglv933' target="_blank">Prophet_CV_trial9</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/3oglv933' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/3oglv933</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2067.11958</td></tr><tr><td>cv_wmae_std</td><td>431.42958</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2575.34918</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial9</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/3oglv933' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/3oglv933</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_092641-3oglv933/logs</code>
# config 9 {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 25.0, 'seasonality_mode': 'additive', 'holidays_prior_scale': 10.0}: CV WMAE=2,067.1
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_092851-5m49i7f8</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/5m49i7f8' target="_blank">Prophet_CV_trial10</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/5m49i7f8' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/5m49i7f8</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>1996.80763</td></tr><tr><td>cv_wmae_std</td><td>396.07005</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2433.4442</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial10</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/5m49i7f8' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/5m49i7f8</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_092851-5m49i7f8/logs</code>
# config 10 {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 25.0, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 1.0}: CV WMAE=1,996.8
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_093108-kh5ozzyw</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/kh5ozzyw' target="_blank">Prophet_CV_trial11</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/kh5ozzyw' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/kh5ozzyw</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2019.91618</td></tr><tr><td>cv_wmae_std</td><td>394.34987</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2434.09023</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial11</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/kh5ozzyw' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/kh5ozzyw</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_093108-kh5ozzyw/logs</code>
# config 11 {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 25.0, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 10.0}: CV WMAE=2,019.9
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_093322-5axgien5</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/5axgien5' target="_blank">Prophet_CV_trial12</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/5axgien5' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/5axgien5</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2012.67427</td></tr><tr><td>cv_wmae_std</td><td>419.45852</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2524.44922</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial12</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/5axgien5' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/5axgien5</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_093322-5axgien5/logs</code>
# config 12 {'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 1.0, 'seasonality_mode': 'additive', 'holidays_prior_scale': 1.0}: CV WMAE=2,012.7
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_093611-d5uyosqs</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/d5uyosqs' target="_blank">Prophet_CV_trial13</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/d5uyosqs' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/d5uyosqs</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2010.18423</td></tr><tr><td>cv_wmae_std</td><td>419.97686</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2523.46852</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial13</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/d5uyosqs' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/d5uyosqs</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_093611-d5uyosqs/logs</code>
# config 13 {'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 1.0, 'seasonality_mode': 'additive', 'holidays_prior_scale': 10.0}: CV WMAE=2,010.2
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_093900-6pcp03hi</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/6pcp03hi' target="_blank">Prophet_CV_trial14</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/6pcp03hi' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/6pcp03hi</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▄█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>1982.95805</td></tr><tr><td>cv_wmae_std</td><td>250.25255</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2296.27441</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial14</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/6pcp03hi' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/6pcp03hi</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_093900-6pcp03hi/logs</code>
# config 14 {'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 1.0, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 1.0}: CV WMAE=1,983.0
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_094152-dh4gke79</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/dh4gke79' target="_blank">Prophet_CV_trial15</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/dh4gke79' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/dh4gke79</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>1951.03944</td></tr><tr><td>cv_wmae_std</td><td>369.56272</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2353.1161</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial15</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/dh4gke79' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/dh4gke79</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_094152-dh4gke79/logs</code>
# config 15 {'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 1.0, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 10.0}: CV WMAE=1,951.0
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_094449-nw7fztm7</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/nw7fztm7' target="_blank">Prophet_CV_trial16</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/nw7fztm7' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/nw7fztm7</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▄█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2018.63358</td></tr><tr><td>cv_wmae_std</td><td>426.38866</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2542.60679</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial16</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/nw7fztm7' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/nw7fztm7</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_094449-nw7fztm7/logs</code>
# config 16 {'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'additive', 'holidays_prior_scale': 1.0}: CV WMAE=2,018.6
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_094743-d63b5z0x</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/d63b5z0x' target="_blank">Prophet_CV_trial17</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/d63b5z0x' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/d63b5z0x</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▄█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2021.31558</td></tr><tr><td>cv_wmae_std</td><td>426.47088</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2544.87711</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial17</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/d63b5z0x' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/d63b5z0x</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_094743-d63b5z0x/logs</code>
# config 17 {'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'additive', 'holidays_prior_scale': 10.0}: CV WMAE=2,021.3
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_095057-tu7pmndt</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/tu7pmndt' target="_blank">Prophet_CV_trial18</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/tu7pmndt' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/tu7pmndt</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>1942.00121</td></tr><tr><td>cv_wmae_std</td><td>369.69067</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2388.16311</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial18</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/tu7pmndt' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/tu7pmndt</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_095057-tu7pmndt/logs</code>
# config 18 {'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 1.0}: CV WMAE=1,942.0
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_095357-6uf5gqqm</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/6uf5gqqm' target="_blank">Prophet_CV_trial19</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...
#  View run <strong style="color:#cdcd00">Prophet_CV_trial41</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/b89hj9pn' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/b89hj9pn</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_111834-b89hj9pn/logs</code>
# config 41 {'changepoint_prior_scale': 0.5, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'additive', 'holidays_prior_scale': 10.0}: CV WMAE=2,108.0
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_112405-frify42l</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/frify42l' target="_blank">Prophet_CV_trial42</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/frify42l' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/frify42l</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▄█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2532.40313</td></tr><tr><td>cv_wmae_std</td><td>719.92063</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>3424.07552</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial42</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/frify42l' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/frify42l</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_112405-frify42l/logs</code>
# config 42 {'changepoint_prior_scale': 0.5, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 1.0}: CV WMAE=2,532.4
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_113004-fka90wr1</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/fka90wr1' target="_blank">Prophet_CV_trial43</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/fka90wr1' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/fka90wr1</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>3547.38727</td></tr><tr><td>cv_wmae_std</td><td>1481.97373</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>4256.22002</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial43</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/fka90wr1' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/fka90wr1</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_113004-fka90wr1/logs</code>
# config 43 {'changepoint_prior_scale': 0.5, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 10.0}: CV WMAE=3,547.4
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_113609-p3byyjeq</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/p3byyjeq' target="_blank">Prophet_CV_trial44</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/p3byyjeq' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/p3byyjeq</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▄█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2112.03292</td></tr><tr><td>cv_wmae_std</td><td>447.47508</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2670.39286</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial44</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/p3byyjeq' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/p3byyjeq</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_113609-p3byyjeq/logs</code>
# config 44 {'changepoint_prior_scale': 0.5, 'seasonality_prior_scale': 25.0, 'seasonality_mode': 'additive', 'holidays_prior_scale': 1.0}: CV WMAE=2,112.0
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_114136-jl4t4x3n</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/jl4t4x3n' target="_blank">Prophet_CV_trial45</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/jl4t4x3n' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/jl4t4x3n</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2125.3707</td></tr><tr><td>cv_wmae_std</td><td>448.91598</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>2671.27555</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial45</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/jl4t4x3n' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/jl4t4x3n</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_114136-jl4t4x3n/logs</code>
# config 45 {'changepoint_prior_scale': 0.5, 'seasonality_prior_scale': 25.0, 'seasonality_mode': 'additive', 'holidays_prior_scale': 10.0}: CV WMAE=2,125.4
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_114701-66uxzozp</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/66uxzozp' target="_blank">Prophet_CV_trial46</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/66uxzozp' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/66uxzozp</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>2651.71307</td></tr><tr><td>cv_wmae_std</td><td>442.79511</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>3277.86156</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial46</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/66uxzozp' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/66uxzozp</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_114701-66uxzozp/logs</code>
# config 46 {'changepoint_prior_scale': 0.5, 'seasonality_prior_scale': 25.0, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 1.0}: CV WMAE=2,651.7
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_115255-nmm8z84x</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/nmm8z84x' target="_blank">Prophet_CV_trial47</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/nmm8z84x' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/nmm8z84x</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>▁</td></tr><tr><td>cv_wmae_std</td><td>▁</td></tr><tr><td>fold</td><td>▁▅█</td></tr><tr><td>fold_wmae</td><td>▁██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cv_wmae_mean</td><td>4250.21388</td></tr><tr><td>cv_wmae_std</td><td>1920.13824</td></tr><tr><td>fold</td><td>2</td></tr><tr><td>fold_wmae</td><td>5714.35298</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_CV_trial47</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/nmm8z84x' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/nmm8z84x</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_115255-nmm8z84x/logs</code>
# config 47 {'changepoint_prior_scale': 0.5, 'seasonality_prior_scale': 25.0, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 10.0}: CV WMAE=4,250.2
# best config: {'changepoint_prior_scale': 0.1, 'seasonality_prior_scale': 1.0, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 10.0} | CV WMAE: 1936.9951378365622

# %% [markdown]
# ## Run 3 results — visual comparison

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pathlib

cv_df = pd.DataFrame([
    {**t['config'], 'cv_wmae_mean': t['cv_wmae_mean']}
    for t in trial_results
]).sort_values('cv_wmae_mean').reset_index(drop=True)

fig, axes = plt.subplots(1, 2, figsize=(16, 10), gridspec_kw={'width_ratios': [1, 1.2]})

labels = [f"cp={r.changepoint_prior_scale:g} sp={r.seasonality_prior_scale:g} {r.seasonality_mode[:4]} hp={r.holidays_prior_scale:g}" for r in cv_df.itertuples()]
bar_colors = ['#c0392b' if i == 0 else '#5b8fd6' for i in range(len(cv_df))]
axes[0].barh(range(len(cv_df)), cv_df['cv_wmae_mean'], color=bar_colors)
axes[0].set_yticks(range(len(cv_df)))
axes[0].set_yticklabels(labels, fontsize=5.5)
axes[0].invert_yaxis()
axes[0].set_xlabel('CV WMAE (mean over 3 folds)')
axes[0].set_title(f'All {len(cv_df)} configs, sorted best -> worst')
axes[0].grid(axis='x', alpha=0.3)

best_mode = cv_df.iloc[0]['seasonality_mode']
best_hp = cv_df.iloc[0]['holidays_prior_scale']
subset = cv_df[(cv_df['seasonality_mode'] == best_mode) & (cv_df['holidays_prior_scale'] == best_hp)]
pivot = subset.pivot(index='changepoint_prior_scale', columns='seasonality_prior_scale', values='cv_wmae_mean')
sns.heatmap(pivot, annot=True, fmt=',.0f', cmap='RdYlGn_r', ax=axes[1], cbar_kws={'label': 'CV WMAE'})
axes[1].set_title(f'changepoint x seasonality prior scale\n@ {best_mode}, holidays_prior_scale={best_hp:g}')

plt.tight_layout()

cv_csv_path = pathlib.Path(WORKING_DIR) / 'prophet_cv_results.csv'
cv_df.to_csv(cv_csv_path, index=False)

with mlflow.start_run(run_name=f'{MODEL_NAME}_CV_Summary'):
    mlflow.log_figure(fig, 'cv_comparison.png')
    mlflow.log_artifact(str(cv_csv_path))

run = wandb.init(project=WANDB_PROJECT, group=MODEL_NAME, job_type='cv_summary', name=f'{MODEL_NAME}_CV_Summary')
wandb.log({'cv_comparison': wandb.Image(fig), 'cv_results_table': wandb.Table(dataframe=cv_df)})
run.finish()

plt.show()
# Out:
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_115855-dgwys18d</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/dgwys18d' target="_blank">Prophet_CV_Summary</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/dgwys18d' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/dgwys18d</a>
#  View run <strong style="color:#cdcd00">Prophet_CV_Summary</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/dgwys18d' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/dgwys18d</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 2 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_115855-dgwys18d/logs</code>

# %% [markdown]
# ## Run 4 — Final fit + save Pipeline

# %%
run = wandb.init(project=WANDB_PROJECT, group=MODEL_NAME, job_type='final', name=f'{MODEL_NAME}_Final', config=best_config)

with mlflow.start_run(run_name=f'{MODEL_NAME}_Final') as mlflow_run:
    mlflow.log_params(best_config)

    holdout_tr, holdout_va = time_holdout(raw_train, weeks=39)
    p = PerSeriesProphetForecaster(**best_config)
    p.fit(raw_train.iloc[holdout_tr], raw_train.iloc[holdout_tr]['Weekly_Sales'])
    hv = raw_train.iloc[holdout_va]
    holdout_pred = p.predict(hv)
    holdout_wmae = wmae(hv['Weekly_Sales'], holdout_pred, hv['IsHoliday'])
    wandb.log({'val_WMAE': holdout_wmae, 'n_failed_fits': p.n_failed_, 'n_series': p.n_series_})
    mlflow.log_metric('val_WMAE', holdout_wmae)
    mlflow.log_metric('n_failed_fits', p.n_failed_)
    print(f'39w-holdout WMAE (val_WMAE): {holdout_wmae} | {p.n_failed_}/{p.n_series_} series failed to fit (fell back)')

    final_pipe = PerSeriesProphetForecaster(**best_config)
    final_pipe.fit(raw_train, raw_train['Weekly_Sales'])

    import pickle, pathlib
    from sklearn.pipeline import Pipeline as SkPipeline
    from mlflow.models import infer_signature

    out_dir = pathlib.Path(WORKING_DIR) / 'models' / MODEL_NAME
    out_dir.mkdir(parents=True, exist_ok=True)
    with open(out_dir / 'pipeline.pkl', 'wb') as f:
        pickle.dump(final_pipe, f)
    wandb.log_artifact(str(out_dir), name=f'{MODEL_NAME}_pipeline', type='model')

    sk_pipe = SkPipeline([('model', final_pipe)])
    example = raw_test.head(5)
    sig = infer_signature(example, final_pipe.predict(example))
    mlflow.sklearn.log_model(sk_pipe, artifact_path='pipeline', signature=sig, input_example=example, serialization_format='cloudpickle')
    mlflow.log_param('test_horizon', int(raw_test['Date'].nunique()))

run.finish()
print('saved pipeline to', out_dir, '| MLflow run:', mlflow_run.info.run_id)
# Out:
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_115904-rvkfyccj</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/rvkfyccj' target="_blank">Prophet_Final</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/rvkfyccj' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/rvkfyccj</a>
# 39w-holdout WMAE (val_WMAE): 1798.2279961649322 | 0/3306 series failed to fit (fell back)
# wandb: Adding directory to artifact (/kaggle/working/models/Prophet)... Done. 0.2s
# /usr/local/lib/python3.12/dist-packages/mlflow/types/utils.py:440: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2026/07/17 12:10:10 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/07/17 12:10:10 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>n_failed_fits</td><td>▁</td></tr><tr><td>n_series</td><td>▁</td></tr><tr><td>val_WMAE</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>n_failed_fits</td><td>0</td></tr><tr><td>n_series</td><td>3306</td></tr><tr><td>val_WMAE</td><td>1798.228</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_Final</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/rvkfyccj' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/rvkfyccj</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_115904-rvkfyccj/logs</code>
# saved pipeline to /kaggle/working/models/Prophet | MLflow run: 36efd9fc0ca34a7f8d9c9bb0ee957704

# %% [markdown]
# ## Run 4 results — holdout diagnostics

# %%
fig, axes = plt.subplots(2, 3, figsize=(19, 10))

ax = axes[0, 0]
ax.scatter(hv['Weekly_Sales'], holdout_pred, s=8, alpha=0.25, color='#5b8fd6')
lims = [0, max(hv['Weekly_Sales'].max(), holdout_pred.max())]
ax.plot(lims, lims, 'r--', lw=1.5, label='perfect prediction')
ax.set_xlabel('Actual Weekly_Sales')
ax.set_ylabel('Predicted Weekly_Sales')
ax.set_title('Actual vs Predicted (holdout)')
ax.legend()
ax.grid(alpha=0.3)

ax = axes[0, 1]
residuals = hv['Weekly_Sales'].to_numpy() - holdout_pred
ax.hist(residuals, bins=60, color='#5b8fd6', edgecolor='black', alpha=0.8)
ax.axvline(0, color='r', linestyle='--', lw=1.5)
ax.set_xlabel('Residual (actual - predicted)')
ax.set_ylabel('Count')
ax.set_title(f'Residual distribution (mean={residuals.mean():,.0f}, std={residuals.std():,.0f})')
ax.grid(alpha=0.3)

ax = axes[0, 2]
agg = hv.assign(pred=holdout_pred).groupby('Date')[['Weekly_Sales', 'pred']].sum()
ax.plot(agg.index, agg['Weekly_Sales'], marker='o', label='Actual', color='#2c3e50')
ax.plot(agg.index, agg['pred'], marker='o', label='Predicted', color='#c0392b')
ax.set_xlabel('Date')
ax.set_ylabel('Total Weekly_Sales (all series)')
ax.set_title('Aggregate sales, actual vs predicted (holdout weeks)')
ax.legend()
ax.grid(alpha=0.3)
plt.setp(ax.get_xticklabels(), rotation=30, ha='right')

ax = axes[1, 0]
holiday_mask = hv['IsHoliday'].to_numpy().astype(bool)
wmae_holiday = wmae(hv['Weekly_Sales'][holiday_mask], holdout_pred[holiday_mask], hv['IsHoliday'][holiday_mask]) if holiday_mask.any() else float('nan')
wmae_non_holiday = wmae(hv['Weekly_Sales'][~holiday_mask], holdout_pred[~holiday_mask], hv['IsHoliday'][~holiday_mask])
bars = ax.bar(['Holiday weeks (w=5)', 'Non-holiday weeks (w=1)'], [wmae_holiday, wmae_non_holiday], color=['#c0392b', '#5b8fd6'])
ax.bar_label(bars, fmt='%.0f')
ax.axhline(holdout_wmae, color='black', linestyle='--', lw=1.5, label=f'Overall WMAE={holdout_wmae:,.0f}')
ax.set_ylabel('WMAE')
ax.set_title('Where the error is coming from')
ax.legend()
ax.grid(axis='y', alpha=0.3)

ax = axes[1, 1]
fitted_keys = [k for k, m in p.models_.items() if m is not None]
sample_key = max(fitted_keys, key=lambda k: p.last_date_[k])
sample_model = p.models_[sample_key]
hist = raw_train[(raw_train['Store'] == sample_key[0]) & (raw_train['Dept'] == sample_key[1])].sort_values('Date')
components = sample_model.predict(pd.DataFrame({'ds': hist['Date']}))
ax.plot(components['ds'], components['yhat'], label='yhat (trend + seasonality + holidays)', color='#c0392b', lw=1.2)
ax.plot(components['ds'], components['trend'], label='trend only', color='#2c3e50', lw=1.8)
for hol_dates, hol_name in [(SUPER_BOWL, None), (LABOR_DAY, None), (THANKSGIVING, None), (CHRISTMAS, None)]:
    in_range = hol_dates[(hol_dates >= hist['Date'].min()) & (hol_dates <= hist['Date'].max())]
    for d in in_range:
        ax.axvline(d, color='#27ae60', linestyle=':', lw=1, alpha=0.6)
ax.set_title(f'Prophet decomposition, Store {sample_key[0]} Dept {sample_key[1]}\n(green dotted = holiday weeks)')
ax.set_xlabel('Date')
ax.set_ylabel('Weekly_Sales')
ax.legend(fontsize=7)
ax.grid(alpha=0.3)
plt.setp(ax.get_xticklabels(), rotation=30, ha='right')

axes[1, 2].axis('off')

plt.tight_layout()

diag_run = mlflow.start_run(run_name=f'{MODEL_NAME}_Final_Diagnostics')
mlflow.log_figure(fig, 'holdout_diagnostics.png')
mlflow.log_metric('holdout_wmae_holiday', wmae_holiday)
mlflow.log_metric('holdout_wmae_non_holiday', wmae_non_holiday)
mlflow.end_run()

wandb_diag_run = wandb.init(project=WANDB_PROJECT, group=MODEL_NAME, job_type='final_diagnostics', name=f'{MODEL_NAME}_Final_Diagnostics')
wandb.log({'holdout_diagnostics': wandb.Image(fig), 'holdout_wmae': holdout_wmae, 'holdout_wmae_holiday': wmae_holiday, 'holdout_wmae_non_holiday': wmae_non_holiday})
wandb_diag_run.finish()

plt.show()
# Out:
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260717_121035-4lxglokm</code>
# Syncing run <strong><a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/4lxglokm' target="_blank">Prophet_Final_Diagnostics</a></strong> to <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a>
#  View run at <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/4lxglokm' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/4lxglokm</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>holdout_wmae</td><td>▁</td></tr><tr><td>holdout_wmae_holiday</td><td>▁</td></tr><tr><td>holdout_wmae_non_holiday</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>holdout_wmae</td><td>1798.228</td></tr><tr><td>holdout_wmae_holiday</td><td>1777.02343</td></tr><tr><td>holdout_wmae_non_holiday</td><td>1803.99914</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Prophet_Final_Diagnostics</strong> at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/4lxglokm' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting/runs/4lxglokm</a><br> View project at: <a href='https://wandb.ai/TwoMusketeers/walmart-sales-forecasting' target="_blank">https://wandb.ai/TwoMusketeers/walmart-sales-forecasting</a><br>Synced 4 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_121035-4lxglokm/logs</code>
